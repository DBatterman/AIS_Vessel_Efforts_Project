# %%
from sqlalchemy import create_engine
import psycopg2
import sqlalchemy as sq
import os
import pandas as pd

# %%
data_dir = "C:/Users/Nodak/Documents/GitHub/AIS_PROJECT/ETL/AIS_RAW_DATA"
file_list = os.listdir(data_dir)
# Out:
# ['2018_01_01_AIS.csv',
#  '2018_01_02_AIS.csv',
#  '2018_01_03_AIS.csv',
#  '2018_01_04_AIS.csv',
#  '2018_01_05_AIS.csv',
#  '2018_01_06_AIS.csv',
#  '2018_01_07_AIS.csv',
#  '2018_01_08_AIS.csv',
#  '2018_01_09_AIS.csv',
#  '2018_01_10_AIS.csv',
#  '2018_01_11_AIS.csv',
#  '2018_01_12_AIS.csv',
#  '2018_01_13_AIS.csv',
#  '2018_01_14_AIS.csv',
#  '2018_01_15_AIS.csv',
#  '2018_01_16_AIS.csv',
#  '2018_01_17_AIS.csv',
#  '2018_01_18_AIS.csv',
#  '2018_01_19_AIS.csv',
#  '2018_01_20_AIS.csv',
#  '2018_01_21_AIS.csv',
#  '2018_01_22_AIS.csv',
#  '2018_01_23_AIS.csv',
#  '2018_01_24_AIS.csv',
#  '2018_01_25_AIS.csv',
#  '2018_01_26_AIS.csv',
#  '2018_01_27_AIS.csv',
#  '2018_01_28_AIS.csv',
#  '2018_01_29_AIS.csv',
#  '2018_01_30_AIS.csv',
#  '2018_01_31_AIS.csv',
#  '2018_02_01_AIS.csv',
#  '2018_02_02_AIS.csv',
#  '2018_02_03_AIS.csv',
#  '2018_02_04_AIS.csv',
#  '2018_02_05_AIS.csv',
#  '2018_02_06_AIS.csv',
#  '2018_02_07_AIS.csv',
#  '2018_02_08_AIS.csv',
#  '2018_02_09_AIS.csv',
# ...

# %%
        # create SQL table for movies_df
connection = f"postgresql://postgres:{password}@127.0.0.1:5432/AIS_Project"
engine = create_engine(connection)

for file in file_list:
    df = pd.read_csv(f"{data_dir}/{file}")
    df.to_sql(name='ais_raw_data', con=engine, dtype={"BaseDateTime": sq.DateTime()}, if_exists='append')
    print(f"Completed upload of... {file}")
# Out:
# Completed upload of... 2018_01_01_AIS.csv
# Completed upload of... 2018_01_02_AIS.csv
# Completed upload of... 2018_01_03_AIS.csv
# Completed upload of... 2018_01_04_AIS.csv
# Completed upload of... 2018_01_05_AIS.csv
# Completed upload of... 2018_01_06_AIS.csv
# Completed upload of... 2018_01_07_AIS.csv
# Completed upload of... 2018_01_08_AIS.csv
# Completed upload of... 2018_01_09_AIS.csv
# Completed upload of... 2018_01_10_AIS.csv
# Completed upload of... 2018_01_11_AIS.csv
# Completed upload of... 2018_01_12_AIS.csv
# Completed upload of... 2018_01_13_AIS.csv
# Completed upload of... 2018_01_14_AIS.csv
# Completed upload of... 2018_01_15_AIS.csv
# Completed upload of... 2018_01_16_AIS.csv
# Completed upload of... 2018_01_17_AIS.csv
# Completed upload of... 2018_01_18_AIS.csv
# Completed upload of... 2018_01_19_AIS.csv
# Completed upload of... 2018_01_20_AIS.csv
# Completed upload of... 2018_01_21_AIS.csv
# Completed upload of... 2018_01_22_AIS.csv
# ...
