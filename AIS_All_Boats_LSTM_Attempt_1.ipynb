# %%
# Import our dependencies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Fix a random seed so the data can be reproduced
np.random.seed(24)

# Upload and read the csv files
ais_df = pd.read_csv("ml_data_daily_2018.csv", index_col=0)

# %%
# Look at our data
ais_df.head()
# Out:
#             Fishing  TugTow  Recreational  Passenger  Cargo  Tanker  Other  \
# 2018/01/01        9      37           145         44     27      13     12
# 2018/01/02       13      45           119         41     27      14     19
# 2018/01/03       13      44           106         40     36      14     20
# 2018/01/04       15      44           103         45     30      10     15
# 2018/01/05       10      45           107         41     26      13     21
#
#             Unavailable
# 2018/01/01            7
# 2018/01/02           10
# 2018/01/03           11
# 2018/01/04           12
# 2018/01/05           10

# %%
# Creating a total column for our data
ais_df['Total']= ais_df.sum(numeric_only=True, axis=1)
ais_df.head()
# Out:
#             Fishing  TugTow  Recreational  Passenger  Cargo  Tanker  Other  \
# 2018/01/01        9      37           145         44     27      13     12
# 2018/01/02       13      45           119         41     27      14     19
# 2018/01/03       13      44           106         40     36      14     20
# 2018/01/04       15      44           103         45     30      10     15
# 2018/01/05       10      45           107         41     26      13     21
#
#             Unavailable  Total
# 2018/01/01            7    294
# 2018/01/02           10    288
# 2018/01/03           11    284
# 2018/01/04           12    274
# 2018/01/05           10    273

# %%
# And then check the type
ais_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 365 entries, 2018/01/01 to 2018/12/31
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Fishing       365 non-null    int64
#  1   TugTow        365 non-null    int64
#  2   Recreational  365 non-null    int64
#  3   Passenger     365 non-null    int64
#  4   Cargo         365 non-null    int64
#  5   Tanker        365 non-null    int64
#  6   Other         365 non-null    int64
#  7   Unavailable   365 non-null    int64
#  8   Total         365 non-null    int64
# dtypes: int64(9)
# memory usage: 28.5+ KB

# %%
# Create nine DataFrames, each with the Date and one unique column:

# Fishing
ais_fishing_df = ais_df.loc[:, ['Fishing']]

# TugTow
ais_tugtow_df = ais_df.loc[:, ['TugTow']]

# Recreational
ais_recreational_df = ais_df.loc[:, ['Recreational']]

# Passenger
ais_passenger_df = ais_df.loc[:, ['Passenger']]

# Cargo
ais_cargo_df = ais_df.loc[:, ['Cargo']]

# Tanker
ais_tanker_df = ais_df.loc[:, ['Tanker']]

# Other
ais_other_df = ais_df.loc[:, ['Other']]

# Unavailable
ais_unavailable_df = ais_df.loc[:, ['Unavailable']]

# Total
ais_total_df = ais_df.loc[:, ['Total']]

# %%
plt.plot(ais_fishing_df)
plt.show()

# %%
# From here, the code is heavily inspired by the code found on this site:
# https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/

# %%
# Convert the nine DataFrames into an arrays, and change the type to floats for the Neural Network

# Fishing
fishing = ais_fishing_df.values
fishing = fishing.astype('float32')

# TugTow
tugtow = ais_tugtow_df.values
tugtow = tugtow.astype('float32')

# Recreational
recreational = ais_recreational_df.values
recreational = recreational.astype('float32')

# Passenger
passenger = ais_passenger_df.values
passenger = passenger.astype('float32')

# Cargo
cargo = ais_cargo_df.values
cargo = cargo.astype('float32')

# Tanker
tanker = ais_tanker_df.values
tanker = tanker.astype('float32')

# Other
other = ais_other_df.values
other = other.astype('float32')

# Unavailable
unavailable = ais_unavailable_df.values
unavailable = unavailable.astype('float32')

# Total
total = ais_total_df.values
total = total.astype('float32')

# %%
# Normalize the data by using a scaler
scaler = MinMaxScaler(feature_range=(0, 1))

# Fishing
fishing = scaler.fit_transform(fishing)

# Tugtow
tugtow = scaler.fit_transform(tugtow)

# Recreational
recreational = scaler.fit_transform(recreational)

# Passenger
passenger = scaler.fit_transform(passenger)

# Cargo
cargo = scaler.fit_transform(cargo)

# Tanker
tanker = scaler.fit_transform(tanker)

# Other
other = scaler.fit_transform(other)

# Unavailable
unavailable = scaler.fit_transform(unavailable)

# Total
total = scaler.fit_transform(total)

# %%
# Create a function that allows the testing/training data to be split into X and Y
# by converting the values of the dataset into a matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
# Define the number of days we are going to look into the past to compare data as look_back. 
look_back = 1

# %% [markdown]
# ### Fishing

# %%
# Split our data into training and testing using slicing, and check the length

train_size_fish = int(len(fishing) * 0.67)
test_size_fish = len(fishing) - train_size_fish
train_fish, test_fish = fishing[0:train_size_fish,:], fishing[train_size_fish:len(total),:]
print(len(train_fish), len(test_fish))
# Out:
# 244 121

# %%
# Reshape the values into X=t and Y=t+1
trainX_fish, trainY_fish = create_dataset(train_fish, look_back)
testX_fish, testY_fish = create_dataset(test_fish, look_back)

# %%
# Reshape the data to incorperate into the LSTM 
trainX_fish = np.reshape(trainX_fish, (trainX_fish.shape[0], 1, trainX_fish.shape[1]))
testX_fish = np.reshape(testX_fish, (testX_fish.shape[0], 1, testX_fish.shape[1]))

# %%
# create and fit the LSTM network
model_fish = Sequential()
model_fish.add(LSTM(4, input_shape=(1, look_back)))
model_fish.add(Dense(1))

# %%
# Check the summary of the model
model_fish.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 4)                 96
#
#  dense (Dense)               (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model_fish.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Train the model
fit_model_fish = model_fish.fit(trainX_fish, trainY_fish, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 242/242 - 2s - loss: 0.1042 - 2s/epoch - 7ms/step
# Epoch 2/100
# 242/242 - 0s - loss: 0.0257 - 372ms/epoch - 2ms/step
# Epoch 3/100
# 242/242 - 0s - loss: 0.0229 - 264ms/epoch - 1ms/step
# Epoch 4/100
# 242/242 - 0s - loss: 0.0218 - 249ms/epoch - 1ms/step
# Epoch 5/100
# 242/242 - 1s - loss: 0.0208 - 563ms/epoch - 2ms/step
# Epoch 6/100
# 242/242 - 1s - loss: 0.0200 - 669ms/epoch - 3ms/step
# Epoch 7/100
# 242/242 - 0s - loss: 0.0194 - 454ms/epoch - 2ms/step
# Epoch 8/100
# 242/242 - 0s - loss: 0.0191 - 428ms/epoch - 2ms/step
# Epoch 9/100
# 242/242 - 0s - loss: 0.0183 - 264ms/epoch - 1ms/step
# Epoch 10/100
# 242/242 - 0s - loss: 0.0180 - 252ms/epoch - 1ms/step
# Epoch 11/100
# 242/242 - 0s - loss: 0.0180 - 375ms/epoch - 2ms/step
# Epoch 12/100
# 242/242 - 0s - loss: 0.0179 - 270ms/epoch - 1ms/step
# Epoch 13/100
# 242/242 - 0s - loss: 0.0175 - 263ms/epoch - 1ms/step
# Epoch 14/100
# 242/242 - 0s - loss: 0.0174 - 281ms/epoch - 1ms/step
# Epoch 15/100
# 242/242 - 0s - loss: 0.0174 - 270ms/epoch - 1ms/step
# Epoch 16/100
# 242/242 - 1s - loss: 0.0173 - 570ms/epoch - 2ms/step
# Epoch 17/100
# 242/242 - 0s - loss: 0.0174 - 444ms/epoch - 2ms/step
# Epoch 18/100
# 242/242 - 0s - loss: 0.0172 - 470ms/epoch - 2ms/step
# Epoch 19/100
# 242/242 - 1s - loss: 0.0172 - 610ms/epoch - 3ms/step
# Epoch 20/100
# 242/242 - 0s - loss: 0.0171 - 278ms/epoch - 1ms/step
# Epoch 21/100
# 242/242 - 0s - loss: 0.0171 - 398ms/epoch - 2ms/step
# Epoch 22/100
# 242/242 - 0s - loss: 0.0173 - 261ms/epoch - 1ms/step
# Epoch 23/100
# 242/242 - 0s - loss: 0.0173 - 255ms/epoch - 1ms/step
# Epoch 24/100
# 242/242 - 0s - loss: 0.0169 - 247ms/epoch - 1ms/step
# Epoch 25/100
# 242/242 - 0s - loss: 0.0174 - 263ms/epoch - 1ms/step
# Epoch 26/100
# 242/242 - 0s - loss: 0.0172 - 259ms/epoch - 1ms/step
# Epoch 27/100
# 242/242 - 0s - loss: 0.0172 - 257ms/epoch - 1ms/step
# Epoch 28/100
# 242/242 - 0s - loss: 0.0174 - 243ms/epoch - 1ms/step
# Epoch 29/100
# 242/242 - 0s - loss: 0.0173 - 260ms/epoch - 1ms/step
# Epoch 30/100
# 242/242 - 0s - loss: 0.0171 - 281ms/epoch - 1ms/step
# Epoch 31/100
# 242/242 - 0s - loss: 0.0171 - 269ms/epoch - 1ms/step
# Epoch 32/100
# 242/242 - 0s - loss: 0.0175 - 250ms/epoch - 1ms/step
# Epoch 33/100
# 242/242 - 0s - loss: 0.0173 - 272ms/epoch - 1ms/step
# Epoch 34/100
# 242/242 - 0s - loss: 0.0172 - 247ms/epoch - 1ms/step
# Epoch 35/100
# 242/242 - 0s - loss: 0.0172 - 252ms/epoch - 1ms/step
# Epoch 36/100
# 242/242 - 0s - loss: 0.0171 - 323ms/epoch - 1ms/step
# Epoch 37/100
# 242/242 - 0s - loss: 0.0174 - 278ms/epoch - 1ms/step
# Epoch 38/100
# 242/242 - 0s - loss: 0.0174 - 261ms/epoch - 1ms/step
# Epoch 39/100
# 242/242 - 0s - loss: 0.0172 - 299ms/epoch - 1ms/step
# Epoch 40/100
# 242/242 - 0s - loss: 0.0173 - 303ms/epoch - 1ms/step
# Epoch 41/100
# 242/242 - 0s - loss: 0.0173 - 310ms/epoch - 1ms/step
# Epoch 42/100
# 242/242 - 0s - loss: 0.0173 - 258ms/epoch - 1ms/step
# Epoch 43/100
# 242/242 - 0s - loss: 0.0172 - 267ms/epoch - 1ms/step
# Epoch 44/100
# 242/242 - 0s - loss: 0.0172 - 281ms/epoch - 1ms/step
# Epoch 45/100
# 242/242 - 0s - loss: 0.0172 - 271ms/epoch - 1ms/step
# Epoch 46/100
# 242/242 - 0s - loss: 0.0168 - 280ms/epoch - 1ms/step
# Epoch 47/100
# 242/242 - 0s - loss: 0.0174 - 253ms/epoch - 1ms/step
# Epoch 48/100
# 242/242 - 0s - loss: 0.0172 - 267ms/epoch - 1ms/step
# Epoch 49/100
# 242/242 - 0s - loss: 0.0172 - 322ms/epoch - 1ms/step
# Epoch 50/100
# 242/242 - 0s - loss: 0.0173 - 287ms/epoch - 1ms/step
# Epoch 51/100
# 242/242 - 0s - loss: 0.0171 - 273ms/epoch - 1ms/step
# Epoch 52/100
# 242/242 - 0s - loss: 0.0173 - 487ms/epoch - 2ms/step
# Epoch 53/100
# 242/242 - 0s - loss: 0.0173 - 273ms/epoch - 1ms/step
# Epoch 54/100
# 242/242 - 0s - loss: 0.0172 - 251ms/epoch - 1ms/step
# Epoch 55/100
# 242/242 - 0s - loss: 0.0171 - 397ms/epoch - 2ms/step
# Epoch 56/100
# 242/242 - 0s - loss: 0.0172 - 272ms/epoch - 1ms/step
# Epoch 57/100
# 242/242 - 0s - loss: 0.0172 - 258ms/epoch - 1ms/step
# Epoch 58/100
# 242/242 - 0s - loss: 0.0173 - 262ms/epoch - 1ms/step
# Epoch 59/100
# 242/242 - 0s - loss: 0.0171 - 244ms/epoch - 1ms/step
# Epoch 60/100
# 242/242 - 0s - loss: 0.0172 - 277ms/epoch - 1ms/step
# Epoch 61/100
# 242/242 - 0s - loss: 0.0173 - 268ms/epoch - 1ms/step
# Epoch 62/100
# 242/242 - 0s - loss: 0.0173 - 265ms/epoch - 1ms/step
# Epoch 63/100
# 242/242 - 0s - loss: 0.0173 - 268ms/epoch - 1ms/step
# Epoch 64/100
# 242/242 - 0s - loss: 0.0173 - 252ms/epoch - 1ms/step
# Epoch 65/100
# 242/242 - 0s - loss: 0.0173 - 271ms/epoch - 1ms/step
# Epoch 66/100
# 242/242 - 0s - loss: 0.0172 - 281ms/epoch - 1ms/step
# Epoch 67/100
# 242/242 - 0s - loss: 0.0174 - 257ms/epoch - 1ms/step
# Epoch 68/100
# 242/242 - 0s - loss: 0.0172 - 253ms/epoch - 1ms/step
# Epoch 69/100
# 242/242 - 0s - loss: 0.0172 - 261ms/epoch - 1ms/step
# Epoch 70/100
# 242/242 - 0s - loss: 0.0172 - 259ms/epoch - 1ms/step
# Epoch 71/100
# 242/242 - 0s - loss: 0.0174 - 280ms/epoch - 1ms/step
# Epoch 72/100
# 242/242 - 0s - loss: 0.0172 - 295ms/epoch - 1ms/step
# Epoch 73/100
# 242/242 - 0s - loss: 0.0173 - 263ms/epoch - 1ms/step
# Epoch 74/100
# 242/242 - 0s - loss: 0.0173 - 255ms/epoch - 1ms/step
# Epoch 75/100
# 242/242 - 0s - loss: 0.0171 - 277ms/epoch - 1ms/step
# Epoch 76/100
# 242/242 - 0s - loss: 0.0174 - 262ms/epoch - 1ms/step
# Epoch 77/100
# 242/242 - 0s - loss: 0.0172 - 259ms/epoch - 1ms/step
# Epoch 78/100
# 242/242 - 0s - loss: 0.0172 - 256ms/epoch - 1ms/step
# Epoch 79/100
# 242/242 - 0s - loss: 0.0172 - 272ms/epoch - 1ms/step
# Epoch 80/100
# 242/242 - 0s - loss: 0.0172 - 299ms/epoch - 1ms/step
# Epoch 81/100
# 242/242 - 0s - loss: 0.0173 - 272ms/epoch - 1ms/step
# Epoch 82/100
# 242/242 - 0s - loss: 0.0173 - 259ms/epoch - 1ms/step
# Epoch 83/100
# 242/242 - 0s - loss: 0.0172 - 282ms/epoch - 1ms/step
# Epoch 84/100
# 242/242 - 0s - loss: 0.0173 - 260ms/epoch - 1ms/step
# Epoch 85/100
# 242/242 - 0s - loss: 0.0172 - 253ms/epoch - 1ms/step
# Epoch 86/100
# 242/242 - 0s - loss: 0.0172 - 289ms/epoch - 1ms/step
# Epoch 87/100
# 242/242 - 0s - loss: 0.0173 - 270ms/epoch - 1ms/step
# Epoch 88/100
# 242/242 - 0s - loss: 0.0172 - 263ms/epoch - 1ms/step
# Epoch 89/100
# 242/242 - 0s - loss: 0.0173 - 297ms/epoch - 1ms/step
# Epoch 90/100
# 242/242 - 0s - loss: 0.0171 - 279ms/epoch - 1ms/step
# Epoch 91/100
# 242/242 - 0s - loss: 0.0173 - 255ms/epoch - 1ms/step
# Epoch 92/100
# 242/242 - 0s - loss: 0.0172 - 275ms/epoch - 1ms/step
# Epoch 93/100
# 242/242 - 0s - loss: 0.0170 - 268ms/epoch - 1ms/step
# Epoch 94/100
# 242/242 - 0s - loss: 0.0173 - 258ms/epoch - 1ms/step
# Epoch 95/100
# 242/242 - 0s - loss: 0.0173 - 274ms/epoch - 1ms/step
# Epoch 96/100
# 242/242 - 0s - loss: 0.0171 - 272ms/epoch - 1ms/step
# Epoch 97/100
# 242/242 - 0s - loss: 0.0172 - 281ms/epoch - 1ms/step
# Epoch 98/100
# 242/242 - 0s - loss: 0.0172 - 260ms/epoch - 1ms/step
# Epoch 99/100
# 242/242 - 0s - loss: 0.0172 - 269ms/epoch - 1ms/step
# Epoch 100/100
# 242/242 - 0s - loss: 0.0172 - 254ms/epoch - 1ms/step

# %%
# Make predictions
trainPredict_fish = model_fish.predict(trainX_fish)
testPredict_fish = model_fish.predict(testX_fish)
# Out:
# 8/8 [==============================] - 0s 992us/step
# 4/4 [==============================] - 0s 2ms/step

# %%
# Invert predictions
trainPredict_fish = scaler.inverse_transform(trainPredict_fish)
trainY_fish = scaler.inverse_transform([trainY_fish])
testPredict_fish = scaler.inverse_transform(testPredict_fish)
testY_fish = scaler.inverse_transform([testY_fish])

# %%
# Calculate root mean squared error
trainScore_fish = math.sqrt(mean_squared_error(trainY_fish[0], trainPredict_fish[:,0]))
print('Train Score: %.2f RMSE' % (trainScore_fish))
testScore_fish = math.sqrt(mean_squared_error(testY_fish[0], testPredict_fish[:,0]))
print('Test Score: %.2f RMSE' % (testScore_fish))
# Out:
# Train Score: 32.44 RMSE
# Test Score: 31.76 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot_fish = np.empty_like(fishing)
trainPredictPlot_fish[:, :] = np.nan
trainPredictPlot_fish[look_back:len(trainPredict_fish)+look_back, :] = trainPredict_fish
# shift test predictions for plotting
testPredictPlot_fish = np.empty_like(fishing)
testPredictPlot_fish[:, :] = np.nan
testPredictPlot_fish[len(trainPredict_fish)+(look_back*2)+1:len(fishing)-1, :] = testPredict_fish
# plot baseline and predictions
plt.plot(scaler.inverse_transform(fishing))
plt.plot(trainPredictPlot_fish)
plt.plot(testPredictPlot_fish)
plt.show()

# %%
scaler.inverse_transform(fishing)
# Out:
# array([[312.23532],
#        [370.82355],
#        [370.82355],
#        [400.11768],
#        [326.8824 ],
#        [341.52942],
#        [400.11768],
#        [326.8824 ],
#        [282.9412 ],
#        [282.9412 ],
#        [400.11768],
#        [400.11768],
#        [400.11768],
#        [370.82355],
#        [370.82355],
#        [341.52942],
#        [400.11768],
#        [370.82355],
#        [326.8824 ],
#        [312.23532],
#        [312.23532],
#        [341.52942],
#        [385.4706 ],
#        [385.4706 ],
#        [326.8824 ],
#        [341.52942],
#        [414.7647 ],
#        [414.7647 ],
#        [414.7647 ],
#        [400.11768],
#        [385.4706 ],
#        [444.05887],
#        [444.05887],
#        [400.11768],
#        [429.41177],
#        [444.05887],
#        [429.41177],
#        [488.     ],
#        [458.7059 ],
#        [444.05887],
#        [414.7647 ],
#        [400.11768],
#        [385.4706 ],
#        [429.41177],
#        [385.4706 ],
#        [356.17648],
#        [356.17648],
#        [326.8824 ],
#        [312.23532],
#        [312.23532],
#        [297.58823],
#        [385.4706 ],
#        [356.17648],
#        [312.23532],
#        [312.23532],
#        [312.23532],
#        [297.58823],
#        [312.23532],
#        [356.17648],
#        [326.8824 ],
#        [297.58823],
#        [356.17648],
#        [326.8824 ],
#        [370.82355],
#        [385.4706 ],
#        [341.52942],
#        [326.8824 ],
#        [356.17648],
#        [400.11768],
#        [414.7647 ],
#        [356.17648],
#        [326.8824 ],
#        [341.52942],
#        [326.8824 ],
#        [370.82355],
#        [400.11768],
#        [385.4706 ],
#        [400.11768],
#        [326.8824 ],
#        [297.58823],
#        [282.9412 ],
#        [282.9412 ],
#        [326.8824 ],
#        [297.58823],
#        [312.23532],
#        [312.23532],
#        [326.8824 ],
#        [341.52942],
#        [312.23532],
#        [326.8824 ],
#        [282.9412 ],
#        [297.58823],
#        [341.52942],
#        [297.58823],
#        [282.9412 ],
#        [326.8824 ],
#        [312.23532],
#        [282.9412 ],
#        [326.8824 ],
#        [326.8824 ],
#        [356.17648],
#        [326.8824 ],
#        [326.8824 ],
#        [326.8824 ],
#        [312.23532],
#        [297.58823],
#        [297.58823],
#        [341.52942],
#        [370.82355],
#        [326.8824 ],
#        [326.8824 ],
#        [326.8824 ],
#        [341.52942],
#        [356.17648],
#        [400.11768],
#        [341.52942],
#        [326.8824 ],
#        [370.82355],
#        [341.52942],
#        [326.8824 ],
#        [312.23532],
#        [297.58823],
#        [312.23532],
#        [356.17648],
#        [341.52942],
#        [312.23532],
#        [356.17648],
#        [341.52942],
#        [312.23532],
#        [268.29413],
#        [268.29413],
#        [282.9412 ],
#        [297.58823],
#        [312.23532],
#        [326.8824 ],
#        [312.23532],
#        [341.52942],
#        [326.8824 ],
#        [326.8824 ],
#        [326.8824 ],
#        [326.8824 ],
#        [297.58823],
#        [341.52942],
#        [400.11768],
#        [341.52942],
#        [341.52942],
#        [326.8824 ],
#        [356.17648],
#        [370.82355],
#        [312.23532],
#        [297.58823],
#        [312.23532],
#        [312.23532],
#        [282.9412 ],
#        [297.58823],
#        [297.58823],
#        [282.9412 ],
#        [282.9412 ],
#        [297.58823],
#        [297.58823],
#        [282.9412 ],
#        [268.29413],
#        [282.9412 ],
#        [268.29413],
#        [297.58823],
#        [326.8824 ],
#        [341.52942],
#        [400.11768],
#        [400.11768],
#        [370.82355],
#        [297.58823],
#        [326.8824 ],
#        [326.8824 ],
#        [341.52942],
#        [341.52942],
#        [326.8824 ],
#        [356.17648],
#        [341.52942],
#        [326.8824 ],
#        [312.23532],
#        [326.8824 ],
#        [370.82355],
#        [341.52942],
#        [297.58823],
#        [312.23532],
#        [341.52942],
#        [326.8824 ],
#        [312.23532],
#        [312.23532],
#        [326.8824 ],
#        [312.23532],
#        [326.8824 ],
#        [370.82355],
#        [385.4706 ],
#        [400.11768],
#        [385.4706 ],
#        [356.17648],
#        [385.4706 ],
#        [444.05887],
#        [341.52942],
#        [312.23532],
#        [356.17648],
#        [414.7647 ],
#        [458.7059 ],
#        [341.52942],
#        [341.52942],
#        [370.82355],
#        [370.82355],
#        [370.82355],
#        [429.41177],
#        [444.05887],
#        [326.8824 ],
#        [312.23532],
#        [312.23532],
#        [341.52942],
#        [282.9412 ],
#        [341.52942],
#        [356.17648],
#        [312.23532],
#        [326.8824 ],
#        [429.41177],
#        [429.41177],
#        [356.17648],
#        [370.82355],
#        [312.23532],
#        [312.23532],
#        [356.17648],
#        [326.8824 ],
#        [370.82355],
#        [370.82355],
#        [356.17648],
#        [326.8824 ],
#        [341.52942],
#        [312.23532],
#        [341.52942],
#        [370.82355],
#        [341.52942],
#        [385.4706 ],
#        [414.7647 ],
#        [356.17648],
#        [414.7647 ],
#        [356.17648],
#        [312.23532],
#        [356.17648],
#        [400.11768],
#        [385.4706 ],
#        [385.4706 ],
#        [400.11768],
#        [341.52942],
#        [385.4706 ],
#        [312.23532],
#        [326.8824 ],
#        [312.23532],
#        [356.17648],
#        [297.58823],
#        [326.8824 ],
#        [400.11768],
#        [370.82355],
#        [341.52942],
#        [385.4706 ],
#        [326.8824 ],
#        [312.23532],
#        [341.52942],
#        [356.17648],
#        [414.7647 ],
#        [341.52942],
#        [370.82355],
#        [400.11768],
#        [356.17648],
#        [356.17648],
#        [356.17648],
#        [356.17648],
#        [326.8824 ],
#        [356.17648],
#        [312.23532],
#        [297.58823],
#        [312.23532],
#        [282.9412 ],
#        [268.29413],
#        [253.64708],
#        [268.29413],
#        [312.23532],
#        [312.23532],
#        [312.23532],
#        [341.52942],
#        [326.8824 ],
#        [326.8824 ],
#        [297.58823],
#        [297.58823],
#        [370.82355],
#        [326.8824 ],
#        [282.9412 ],
#        [341.52942],
#        [282.9412 ],
#        [297.58823],
#        [297.58823],
#        [326.8824 ],
#        [341.52942],
#        [312.23532],
#        [326.8824 ],
#        [282.9412 ],
#        [282.9412 ],
#        [282.9412 ],
#        [282.9412 ],
#        [268.29413],
#        [282.9412 ],
#        [312.23532],
#        [282.9412 ],
#        [297.58823],
#        [312.23532],
#        [297.58823],
#        [297.58823],
#        [326.8824 ],
#        [282.9412 ],
#        [312.23532],
#        [385.4706 ],
#        [400.11768],
#        [458.7059 ],
#        [400.11768],
#        [370.82355],
#        [385.4706 ],
#        [385.4706 ],
#        [370.82355],
#        [341.52942],
#        [326.8824 ],
#        [268.29413],
#        [239.     ],
#        [326.8824 ],
#        [356.17648],
#        [341.52942],
#        [326.8824 ],
#        [341.52942],
#        [326.8824 ],
#        [312.23532],
#        [341.52942],
#        [356.17648],
#        [370.82355],
#        [341.52942],
#        [282.9412 ],
#        [341.52942],
#        [326.8824 ],
#        [326.8824 ],
#        [326.8824 ],
#        [297.58823],
#        [268.29413],
#        [282.9412 ],
#        [341.52942],
#        [312.23532],
#        [297.58823],
#        [282.9412 ],
#        [268.29413],
#        [326.8824 ],
#        [356.17648],
#        [370.82355],
#        [326.8824 ],
#        [312.23532],
#        [341.52942],
#        [326.8824 ],
#        [297.58823],
#        [253.64708],
#        [253.64708],
#        [326.8824 ],
#        [356.17648],
#        [312.23532],
#        [253.64708]], dtype=float32)

# %% [markdown]
# ### TugTow

# %%
# Split our data into training and testing using slicing, and check the length

train_size_tugtow = int(len(tugtow) * 0.67)
test_size_tugtow = len(tugtow) - train_size_tugtow
train_tugtow, test_tugtow = tugtow[0:train_size_tugtow,:], tugtow[train_size_tugtow:len(total),:]
print(len(train_tugtow), len(test_tugtow))
# Out:
# 244 121

# %%
# Reshape the values into X=t and Y=t+1
trainX_tugtow, trainY_tugtow = create_dataset(train_tugtow, look_back)
testX_tugtow, testY_tugtow = create_dataset(test_tugtow, look_back)

# %%
# Reshape the values into X=t and Y=t+1
trainX_tugtow, trainY_tugtow = create_dataset(train_tugtow, look_back)
testX_tugtow, testY_tugtow = create_dataset(test_tugtow, look_back)

# %%
# Reshape the data to incorperate into the LSTM 
trainX_tugtow = np.reshape(trainX_tugtow, (trainX_tugtow.shape[0], 1, trainX_tugtow.shape[1]))
testX_tugtow = np.reshape(testX_tugtow, (testX_tugtow.shape[0], 1, testX_tugtow.shape[1]))

# %%
# create and fit the LSTM network
model_tugtow = Sequential()
model_tugtow.add(LSTM(4, input_shape=(1, look_back)))
model_tugtow.add(Dense(1))

# %%
# Check the summary of the model
model_tugtow.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 4)                 96
#
#  dense_1 (Dense)             (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model_tugtow.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Train the model
fit_model_tugtow = model_tugtow.fit(trainX_tugtow, trainY_tugtow, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 242/242 - 2s - loss: 0.0962 - 2s/epoch - 7ms/step
# Epoch 2/100
# 242/242 - 0s - loss: 0.0197 - 315ms/epoch - 1ms/step
# Epoch 3/100
# 242/242 - 1s - loss: 0.0179 - 661ms/epoch - 3ms/step
# Epoch 4/100
# 242/242 - 0s - loss: 0.0175 - 490ms/epoch - 2ms/step
# Epoch 5/100
# 242/242 - 0s - loss: 0.0170 - 392ms/epoch - 2ms/step
# Epoch 6/100
# 242/242 - 0s - loss: 0.0167 - 285ms/epoch - 1ms/step
# Epoch 7/100
# 242/242 - 1s - loss: 0.0163 - 619ms/epoch - 3ms/step
# Epoch 8/100
# 242/242 - 1s - loss: 0.0160 - 599ms/epoch - 2ms/step
# Epoch 9/100
# 242/242 - 1s - loss: 0.0158 - 637ms/epoch - 3ms/step
# Epoch 10/100
# 242/242 - 0s - loss: 0.0155 - 298ms/epoch - 1ms/step
# Epoch 11/100
# 242/242 - 1s - loss: 0.0153 - 639ms/epoch - 3ms/step
# Epoch 12/100
# 242/242 - 0s - loss: 0.0152 - 331ms/epoch - 1ms/step
# Epoch 13/100
# 242/242 - 0s - loss: 0.0150 - 423ms/epoch - 2ms/step
# Epoch 14/100
# 242/242 - 0s - loss: 0.0149 - 230ms/epoch - 950us/step
# Epoch 15/100
# 242/242 - 0s - loss: 0.0149 - 427ms/epoch - 2ms/step
# Epoch 16/100
# 242/242 - 1s - loss: 0.0147 - 630ms/epoch - 3ms/step
# Epoch 17/100
# 242/242 - 1s - loss: 0.0148 - 703ms/epoch - 3ms/step
# Epoch 18/100
# 242/242 - 0s - loss: 0.0145 - 272ms/epoch - 1ms/step
# Epoch 19/100
# 242/242 - 0s - loss: 0.0149 - 410ms/epoch - 2ms/step
# Epoch 20/100
# 242/242 - 0s - loss: 0.0148 - 295ms/epoch - 1ms/step
# Epoch 21/100
# 242/242 - 1s - loss: 0.0147 - 549ms/epoch - 2ms/step
# Epoch 22/100
# 242/242 - 0s - loss: 0.0148 - 445ms/epoch - 2ms/step
# Epoch 23/100
# 242/242 - 0s - loss: 0.0149 - 321ms/epoch - 1ms/step
# Epoch 24/100
# 242/242 - 0s - loss: 0.0148 - 289ms/epoch - 1ms/step
# Epoch 25/100
# 242/242 - 0s - loss: 0.0146 - 255ms/epoch - 1ms/step
# Epoch 26/100
# 242/242 - 0s - loss: 0.0148 - 273ms/epoch - 1ms/step
# Epoch 27/100
# 242/242 - 0s - loss: 0.0146 - 384ms/epoch - 2ms/step
# Epoch 28/100
# 242/242 - 1s - loss: 0.0146 - 623ms/epoch - 3ms/step
# Epoch 29/100
# 242/242 - 1s - loss: 0.0147 - 665ms/epoch - 3ms/step
# Epoch 30/100
# 242/242 - 0s - loss: 0.0147 - 397ms/epoch - 2ms/step
# Epoch 31/100
# 242/242 - 1s - loss: 0.0148 - 517ms/epoch - 2ms/step
# Epoch 32/100
# 242/242 - 0s - loss: 0.0147 - 492ms/epoch - 2ms/step
# Epoch 33/100
# 242/242 - 0s - loss: 0.0150 - 454ms/epoch - 2ms/step
# Epoch 34/100
# 242/242 - 1s - loss: 0.0148 - 563ms/epoch - 2ms/step
# Epoch 35/100
# 242/242 - 0s - loss: 0.0147 - 303ms/epoch - 1ms/step
# Epoch 36/100
# 242/242 - 0s - loss: 0.0147 - 263ms/epoch - 1ms/step
# Epoch 37/100
# 242/242 - 0s - loss: 0.0147 - 296ms/epoch - 1ms/step
# Epoch 38/100
# 242/242 - 1s - loss: 0.0144 - 564ms/epoch - 2ms/step
# Epoch 39/100
# 242/242 - 0s - loss: 0.0148 - 279ms/epoch - 1ms/step
# Epoch 40/100
# 242/242 - 0s - loss: 0.0147 - 296ms/epoch - 1ms/step
# Epoch 41/100
# 242/242 - 0s - loss: 0.0147 - 289ms/epoch - 1ms/step
# Epoch 42/100
# 242/242 - 0s - loss: 0.0148 - 258ms/epoch - 1ms/step
# Epoch 43/100
# 242/242 - 0s - loss: 0.0147 - 448ms/epoch - 2ms/step
# Epoch 44/100
# 242/242 - 0s - loss: 0.0146 - 365ms/epoch - 2ms/step
# Epoch 45/100
# 242/242 - 0s - loss: 0.0147 - 285ms/epoch - 1ms/step
# Epoch 46/100
# 242/242 - 0s - loss: 0.0146 - 298ms/epoch - 1ms/step
# Epoch 47/100
# 242/242 - 0s - loss: 0.0147 - 263ms/epoch - 1ms/step
# Epoch 48/100
# 242/242 - 0s - loss: 0.0145 - 305ms/epoch - 1ms/step
# Epoch 49/100
# 242/242 - 0s - loss: 0.0147 - 267ms/epoch - 1ms/step
# Epoch 50/100
# 242/242 - 0s - loss: 0.0147 - 240ms/epoch - 992us/step
# Epoch 51/100
# 242/242 - 0s - loss: 0.0146 - 278ms/epoch - 1ms/step
# Epoch 52/100
# 242/242 - 0s - loss: 0.0149 - 304ms/epoch - 1ms/step
# Epoch 53/100
# 242/242 - 0s - loss: 0.0147 - 278ms/epoch - 1ms/step
# Epoch 54/100
# 242/242 - 0s - loss: 0.0147 - 471ms/epoch - 2ms/step
# Epoch 55/100
# 242/242 - 1s - loss: 0.0147 - 568ms/epoch - 2ms/step
# Epoch 56/100
# 242/242 - 0s - loss: 0.0146 - 272ms/epoch - 1ms/step
# Epoch 57/100
# 242/242 - 0s - loss: 0.0147 - 348ms/epoch - 1ms/step
# Epoch 58/100
# 242/242 - 0s - loss: 0.0146 - 242ms/epoch - 1ms/step
# Epoch 59/100
# 242/242 - 0s - loss: 0.0148 - 343ms/epoch - 1ms/step
# Epoch 60/100
# 242/242 - 0s - loss: 0.0146 - 307ms/epoch - 1ms/step
# Epoch 61/100
# 242/242 - 0s - loss: 0.0149 - 283ms/epoch - 1ms/step
# Epoch 62/100
# 242/242 - 0s - loss: 0.0146 - 270ms/epoch - 1ms/step
# Epoch 63/100
# 242/242 - 0s - loss: 0.0146 - 475ms/epoch - 2ms/step
# Epoch 64/100
# 242/242 - 0s - loss: 0.0146 - 243ms/epoch - 1ms/step
# Epoch 65/100
# 242/242 - 0s - loss: 0.0146 - 249ms/epoch - 1ms/step
# Epoch 66/100
# 242/242 - 0s - loss: 0.0147 - 327ms/epoch - 1ms/step
# Epoch 67/100
# 242/242 - 0s - loss: 0.0148 - 345ms/epoch - 1ms/step
# Epoch 68/100
# 242/242 - 0s - loss: 0.0146 - 424ms/epoch - 2ms/step
# Epoch 69/100
# 242/242 - 0s - loss: 0.0148 - 369ms/epoch - 2ms/step
# Epoch 70/100
# 242/242 - 0s - loss: 0.0147 - 267ms/epoch - 1ms/step
# Epoch 71/100
# 242/242 - 0s - loss: 0.0146 - 264ms/epoch - 1ms/step
# Epoch 72/100
# 242/242 - 0s - loss: 0.0148 - 254ms/epoch - 1ms/step
# Epoch 73/100
# 242/242 - 0s - loss: 0.0149 - 265ms/epoch - 1ms/step
# Epoch 74/100
# 242/242 - 0s - loss: 0.0146 - 257ms/epoch - 1ms/step
# Epoch 75/100
# 242/242 - 0s - loss: 0.0147 - 249ms/epoch - 1ms/step
# Epoch 76/100
# 242/242 - 0s - loss: 0.0146 - 264ms/epoch - 1ms/step
# Epoch 77/100
# 242/242 - 0s - loss: 0.0146 - 372ms/epoch - 2ms/step
# Epoch 78/100
# 242/242 - 1s - loss: 0.0146 - 500ms/epoch - 2ms/step
# Epoch 79/100
# 242/242 - 1s - loss: 0.0146 - 564ms/epoch - 2ms/step
# Epoch 80/100
# 242/242 - 1s - loss: 0.0147 - 587ms/epoch - 2ms/step
# Epoch 81/100
# 242/242 - 1s - loss: 0.0148 - 567ms/epoch - 2ms/step
# Epoch 82/100
# 242/242 - 0s - loss: 0.0147 - 305ms/epoch - 1ms/step
# Epoch 83/100
# 242/242 - 0s - loss: 0.0149 - 283ms/epoch - 1ms/step
# Epoch 84/100
# 242/242 - 0s - loss: 0.0148 - 332ms/epoch - 1ms/step
# Epoch 85/100
# 242/242 - 0s - loss: 0.0148 - 319ms/epoch - 1ms/step
# Epoch 86/100
# 242/242 - 0s - loss: 0.0147 - 293ms/epoch - 1ms/step
# Epoch 87/100
# 242/242 - 0s - loss: 0.0146 - 277ms/epoch - 1ms/step
# Epoch 88/100
# 242/242 - 0s - loss: 0.0148 - 263ms/epoch - 1ms/step
# Epoch 89/100
# 242/242 - 0s - loss: 0.0146 - 288ms/epoch - 1ms/step
# Epoch 90/100
# 242/242 - 0s - loss: 0.0147 - 275ms/epoch - 1ms/step
# Epoch 91/100
# 242/242 - 0s - loss: 0.0147 - 297ms/epoch - 1ms/step
# Epoch 92/100
# 242/242 - 0s - loss: 0.0147 - 346ms/epoch - 1ms/step
# Epoch 93/100
# 242/242 - 0s - loss: 0.0148 - 287ms/epoch - 1ms/step
# Epoch 94/100
# 242/242 - 0s - loss: 0.0147 - 279ms/epoch - 1ms/step
# Epoch 95/100
# 242/242 - 0s - loss: 0.0148 - 290ms/epoch - 1ms/step
# Epoch 96/100
# 242/242 - 0s - loss: 0.0148 - 278ms/epoch - 1ms/step
# Epoch 97/100
# 242/242 - 0s - loss: 0.0148 - 250ms/epoch - 1ms/step
# Epoch 98/100
# 242/242 - 0s - loss: 0.0148 - 300ms/epoch - 1ms/step
# Epoch 99/100
# 242/242 - 0s - loss: 0.0146 - 283ms/epoch - 1ms/step
# Epoch 100/100
# 242/242 - 0s - loss: 0.0149 - 246ms/epoch - 1ms/step

# %%
# Make predictions
trainPredict_tugtow = model_tugtow.predict(trainX_tugtow)
testPredict_tugtow = model_tugtow.predict(testX_tugtow)
# Out:
# 8/8 [==============================] - 0s 1ms/step
# 4/4 [==============================] - 0s 996us/step

# %%
# Invert predictions
trainPredict_tugtow = scaler.inverse_transform(trainPredict_tugtow)
trainY_tugtow = scaler.inverse_transform([trainY_tugtow])
testPredict_tugtow = scaler.inverse_transform(testPredict_tugtow)
testY_tugtow = scaler.inverse_transform([testY_tugtow])

# %%
# Calculate root mean squared error
trainScore_tugtow = math.sqrt(mean_squared_error(trainY_tugtow[0], trainPredict_tugtow[:,0]))
print('Train Score: %.2f RMSE' % (trainScore_tugtow))
testScore_tugtow = math.sqrt(mean_squared_error(testY_tugtow[0], testPredict_tugtow[:,0]))
print('Test Score: %.2f RMSE' % (testScore_tugtow))
# Out:
# Train Score: 29.99 RMSE
# Test Score: 38.28 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot_tugtow = np.empty_like(tugtow)
trainPredictPlot_tugtow[:, :] = np.nan
trainPredictPlot_tugtow[look_back:len(trainPredict_tugtow)+look_back, :] = trainPredict_tugtow
# shift test predictions for plotting
testPredictPlot_tugtow = np.empty_like(tugtow)
testPredictPlot_tugtow[:, :] = np.nan
testPredictPlot_tugtow[len(trainPredict_tugtow)+(look_back*2)+1:len(tugtow)-1, :] = testPredict_tugtow
# plot baseline and predictions
plt.plot(scaler.inverse_transform(tugtow))
plt.plot(trainPredictPlot_tugtow)
plt.plot(testPredictPlot_tugtow)
plt.show()
